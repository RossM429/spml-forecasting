# %%
# load packages
import numpy as np
import pandas as pd
from sklearn.linear_model import LinearRegression
from sklearn.preprocessing import OneHotEncoder

# %%
df = pd.read_csv('data/data.csv', parse_dates=['Flight_Date'])

df.drop(['Unnamed: 0', 'Carrier', 'Scheduled_Departure_Time', 'Is_Weekend','Flight_ID', 'Month','Aircraft_Capacity'],axis=1, inplace=True)

df.head()
# Out:
#   Flight_Date    Route  Actual_Pax_Count  Is_Holiday_Period  CHML_Ordered
# 0  2024-01-01  EDI-DXB               220              False             9
# 1  2024-01-01  GLA-DXB               369              False             6
# 2  2024-01-02  EDI-DXB               227              False            21
# 3  2024-01-02  GLA-DXB               384              False            18
# 4  2024-01-03  EDI-DXB               238              False            14

# %%
print(df.dtypes)
# Out:
# Flight_Date          datetime64[ns]
# Route                        object
# Actual_Pax_Count              int64
# Is_Holiday_Period              bool
# CHML_Ordered                  int64
# dtype: object

# %%
X = df.loc[:,['Flight_Date', 'Route', 'Actual_Pax_Count', 'Is_Holiday_Period']]
y = df.loc[:,'CHML_Ordered']

X = pd.get_dummies(X)

X.drop('Route_GLA-DXB', axis=1, inplace=True)

# %%
X['Month'] =
# Out:
#   Cell In[7], line 1
#     X['Month'] =
#                 ^
# SyntaxError: invalid syntax

# %%
reg = LinearRegression().fit(X,y)
reg.score(X,y)
# Out:
# ---------------------------------------------------------------------------
# DTypePromotionError                       Traceback (most recent call last)
# Cell In[35], line 1
# ----> 1 reg = LinearRegression().fit(X,y)
#       2 reg.score(X,y)
#
# File ~/env/server/lib/python3.12/site-packages/sklearn/base.py:1336, in _fit_context.<locals>.decorator.<locals>.wrapper(estimator, *args, **kwargs)
#    1329     estimator._validate_params()
#    1331 with config_context(
#    1332     skip_parameter_validation=(
#    1333         prefer_skip_nested_validation or global_skip_validation
#    1334     )
#    1335 ):
# -> 1336     return fit_method(estimator, *args, **kwargs)
#
# File ~/env/server/lib/python3.12/site-packages/sklearn/linear_model/_base.py:630, in LinearRegression.fit(self, X, y, sample_weight)
#     626 n_jobs_ = self.n_jobs
#     628 accept_sparse = False if self.positive else ["csr", "csc", "coo"]
# --> 630 X, y = validate_data(
#     631     self,
#     632     X,
# ...
